# %%
import numpy as np

# %%
import pandas as pd

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\user'

# %%
os.chdir('Downloads')

# %%
dataset = pd.read_csv('DemographicData.csv')

# %%
dataset
# Out:
#                        Country Name Country Code  Birth rate  Internet users  \
# 0                             Aruba          ABW      10.244        78.90000
# 1                       Afghanistan          AFG      35.253         5.90000
# 2                            Angola          AGO      45.985        19.10000
# 3                           Albania          ALB      12.877        57.20000
# 4              United Arab Emirates          ARE      11.044        88.00000
# 5                         Argentina          ARG      17.716        59.90000
# 6                           Armenia          ARM      13.308        41.90000
# 7               Antigua and Barbuda          ATG      16.447        63.40000
# 8                         Australia          AUS      13.200        83.00000
# 9                           Austria          AUT       9.400        80.61880
# 10                       Azerbaijan          AZE      18.300        58.70000
# ...

# %%
len(dataset)
# Out:
# 195

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 5 columns):
# Country Name      195 non-null object
# Country Code      195 non-null object
# Birth rate        195 non-null float64
# Internet users    195 non-null float64
# Income Group      195 non-null object
# dtypes: float64(2), object(3)
# memory usage: 7.7+ KB

# %%
dataset.columns = ['CountryName','CountryCode','BirthRate','InternetUsers','IncomeGroup']

# %%
dataset
# Out:
#                         CountryName CountryCode  BirthRate  InternetUsers  \
# 0                             Aruba         ABW     10.244       78.90000
# 1                       Afghanistan         AFG     35.253        5.90000
# 2                            Angola         AGO     45.985       19.10000
# 3                           Albania         ALB     12.877       57.20000
# 4              United Arab Emirates         ARE     11.044       88.00000
# 5                         Argentina         ARG     17.716       59.90000
# 6                           Armenia         ARM     13.308       41.90000
# 7               Antigua and Barbuda         ATG     16.447       63.40000
# 8                         Australia         AUS     13.200       83.00000
# 9                           Austria         AUT      9.400       80.61880
# 10                       Azerbaijan         AZE     18.300       58.70000
# 11                          Burundi         BDI     44.151        1.30000
# ...

# %%
dataset.rename(columns={'BirthRate':'BR'},inplace=True)

# %%
dataset= dataset.rename(columns={'BR':'BirthRate'})

# %%
dataset[1:4]
# Out:
#    CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup
# 1  Afghanistan         AFG     35.253            5.9           Low income
# 2       Angola         AGO     45.985           19.1  Upper middle income
# 3      Albania         ALB     12.877           57.2  Upper middle income

# %%
dataset[1:4][['CountryName','InternetUsers']]
# Out:
#    CountryName  InternetUsers
# 1  Afghanistan            5.9
# 2       Angola           19.1
# 3      Albania           57.2

# %%
dataset['Mycalc']=dataset.BirthRate*dataset.InternetUsers

# %%
dataset
# Out:
#                         CountryName CountryCode  BirthRate  InternetUsers  \
# 0                             Aruba         ABW     10.244       78.90000
# 1                       Afghanistan         AFG     35.253        5.90000
# 2                            Angola         AGO     45.985       19.10000
# 3                           Albania         ALB     12.877       57.20000
# 4              United Arab Emirates         ARE     11.044       88.00000
# 5                         Argentina         ARG     17.716       59.90000
# 6                           Armenia         ARM     13.308       41.90000
# 7               Antigua and Barbuda         ATG     16.447       63.40000
# 8                         Australia         AUS     13.200       83.00000
# 9                           Austria         AUT      9.400       80.61880
# 10                       Azerbaijan         AZE     18.300       58.70000
# 11                          Burundi         BDI     44.151        1.30000
# ...

# %%
dataset.sort_values(['Mycalc'],ascending=0)
# Out:
#                   CountryName CountryCode  BirthRate  InternetUsers  \
# 96                     Kuwait         KWT     20.575       75.46000
# 128                   Nigeria         NGA     40.045       38.00000
# 85                     Israel         ISR     21.300       70.80000
# 188        West Bank and Gaza         PSE     30.394       46.60000
# 91                      Kenya         KEN     35.194       39.00000
# 134                      Oman         OMN     20.419       66.45000
# 17                    Bahrain         BHR     15.040       90.00004
# 84                    Iceland         ISL     13.400       96.54680
# 149              Saudi Arabia         SAU     20.576       60.50000
# 90                 Kazakhstan         KAZ     22.730       54.00000
# 109                   Morocco         MAR     21.023       56.00000
# 81                    Ireland         IRL     15.000       78.24770
# 72                       Guam         GUM     17.389       65.40000
# ...

# %%
dataset.sort_values(['Mycalc'],ascending=1)
# Out:
#                   CountryName CountryCode  BirthRate  InternetUsers  \
# 117                   Myanmar         MMR     18.119        1.60000
# 52                    Eritrea         ERI     34.800        0.90000
# 172               Timor-Leste         TLS     35.755        1.10000
# 11                    Burundi         BDI     44.151        1.30000
# 64                     Guinea         GIN     37.337        1.60000
# 154              Sierra Leone         SLE     36.729        1.70000
# 55                   Ethiopia         ETH     32.925        1.90000
# 156                   Somalia         SOM     43.891        1.50000
# 127                     Niger         NER     49.661        1.70000
# 192          Congo, Dem. Rep.         COD     42.394        2.20000
# 111                Madagascar         MDG     34.686        3.00000
# 167                      Chad         TCD     45.745        2.30000
# 99                    Liberia         LBR     35.521        3.20000
# ...

# %%
dataset.drop('Mycalc',1)
# Out:
#                         CountryName CountryCode  BirthRate  InternetUsers  \
# 0                             Aruba         ABW     10.244       78.90000
# 1                       Afghanistan         AFG     35.253        5.90000
# 2                            Angola         AGO     45.985       19.10000
# 3                           Albania         ALB     12.877       57.20000
# 4              United Arab Emirates         ARE     11.044       88.00000
# 5                         Argentina         ARG     17.716       59.90000
# 6                           Armenia         ARM     13.308       41.90000
# 7               Antigua and Barbuda         ATG     16.447       63.40000
# 8                         Australia         AUS     13.200       83.00000
# 9                           Austria         AUT      9.400       80.61880
# 10                       Azerbaijan         AZE     18.300       58.70000
# 11                          Burundi         BDI     44.151        1.30000
# ...

# %%
dataset=dataset.drop('Mycalc',1)

# %%
dataset
# Out:
#                         CountryName CountryCode  BirthRate  InternetUsers  \
# 0                             Aruba         ABW     10.244       78.90000
# 1                       Afghanistan         AFG     35.253        5.90000
# 2                            Angola         AGO     45.985       19.10000
# 3                           Albania         ALB     12.877       57.20000
# 4              United Arab Emirates         ARE     11.044       88.00000
# 5                         Argentina         ARG     17.716       59.90000
# 6                           Armenia         ARM     13.308       41.90000
# 7               Antigua and Barbuda         ATG     16.447       63.40000
# 8                         Australia         AUS     13.200       83.00000
# 9                           Austria         AUT      9.400       80.61880
# 10                       Azerbaijan         AZE     18.300       58.70000
# 11                          Burundi         BDI     44.151        1.30000
# ...

# %%
dataset[dataset['CountryName']='Aruba']
# Out:
#   File "<ipython-input-23-23a4b76fdd13>", line 1
#     dataset[dataset['CountryName']='Aruba']
#                                   ^
# SyntaxError: invalid syntax

# %%
dataset.IncomeGroup()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-15089b12bee6> in <module>
# ----> 1 dataset.IncomeGroup()
#
# TypeError: 'Series' object is not callable

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
sns.lmplot(data=dataset,x='InternetUsers',y='BirthRate')

# %%
sns.lmplot(data=dataset,x='InternetUsers',y='BirthRate',fit_reg=False,hue='IncomeGroup')

# %%
df1=pd.DataFrame(np.array([['a',5,9],['b',4,6],['c',24,9]]))

# %%
df1=pd.DataFrame(np.array([['a',5,9],['b',4,6],['c',24,9]]),columns=['Name','aatr1','attr2'])

# %%
df2=pd.DataFrame(np.array([['a',5,9],['d',2,6],['e',8,5]]),columns=['Name','aatr3','attr4'])

# %%
df3=pd.DataFrame(np.array([['a',5,9],['f',7,6],['g',4,3]]),columns=['Name','aatr5','attr6'])

# %%
pd.merge(df1,df2,how='inner')
# Out:
#   Name aatr1 attr2 aatr3 attr4
# 0    a     5     9     5     9

# %%
pd.merge(df3,pd.merge(df1,df2,how='inner'),how='inner')
# Out:
#   Name aatr5 attr6 aatr1 attr2 aatr3 attr4
# 0    a     5     9     5     9     5     9

# %%
df1.merge(df2,on='Name').merge(df3,on='Name')
# Out:
#   Name aatr1 attr2 aatr3 attr4 aatr5 attr6
# 0    a     5     9     5     9     5     9
