# %%
import pandas as pd

# %%
primary_data = {'student_id':[1,2,3,4],
               'first_name':['sam','ben','ven','alex'],
               'last_name':['chan','charlie','mathew','thomas']}

# %%
primary_data
# Out:
# {'student_id': [1, 2, 3, 4],
#  'first_name': ['sam', 'ben', 'ven', 'alex'],
#  'last_name': ['chan', 'charlie', 'mathew', 'thomas']}

# %%
student_details=pd.DataFrame(primary_data)

# %%
student_details
# Out:
#    student_id first_name last_name
# 0           1        sam      chan
# 1           2        ben   charlie
# 2           3        ven    mathew
# 3           4       alex    thomas

# %%
student_details['first_name']
# Out:
# 0     sam
# 1     ben
# 2     ven
# 3    alex
# Name: first_name, dtype: object

# %%
type(student_details)
# Out:
# pandas.core.frame.DataFrame

# %%
type(student_details['first_name'])
# Out:
# pandas.core.series.Series

# %%
type(student_details['last_name'])
# Out:
# pandas.core.series.Series

# %%
student_details[['first_name']]
# Out:
#   first_name
# 0        sam
# 1        ben
# 2        ven
# 3       alex

# %%
type(student_details[['first_name']])
# Out:
# pandas.core.frame.DataFrame

# %%
student_details[1:4]
# Out:
#    student_id first_name last_name
# 1           2        ben   charlie
# 2           3        ven    mathew
# 3           4       alex    thomas

# %%
student_details.iloc[ : ,1:3]
# Out:
#   first_name last_name
# 0        sam      chan
# 1        ben   charlie
# 2        ven    mathew
# 3       alex    thomas

# %%
secondary_data = {'stud_id':[1,2,3,5],
                 'student_course':['ML','DS','AI','BI'],
                 'duration':[2,4,6,8]}

# %%
secondary_data
# Out:
# {'stud_id': [1, 2, 3, 5],
#  'student_course': ['ML', 'DS', 'AI', 'BI'],
#  'duration': [2, 4, 6, 8]}

# %%
student_credentials = pd.DataFrame(secondary_data)

# %%
student_credentials
# Out:
#    stud_id student_course  duration
# 0        1             ML         2
# 1        2             DS         4
# 2        3             AI         6
# 3        5             BI         8

# %%
pd.concat([student_details,student_credentials],axis=0)
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.
#    duration first_name last_name  stud_id student_course  student_id
# 0       NaN        sam      chan      NaN            NaN         1.0
# 1       NaN        ben   charlie      NaN            NaN         2.0
# 2       NaN        ven    mathew      NaN            NaN         3.0
# 3       NaN       alex    thomas      NaN            NaN         4.0
# 0       2.0        NaN       NaN      1.0             ML         NaN
# 1       4.0        NaN       NaN      2.0             DS         NaN
# 2       6.0        NaN       NaN      3.0             AI         NaN
# ...

# %%
pd.concat([student_details,student_credentials],axis=1)
# Out:
#    student_id first_name last_name  stud_id student_course  duration
# 0           1        sam      chan        1             ML         2
# 1           2        ben   charlie        2             DS         4
# 2           3        ven    mathew        3             AI         6
# 3           4       alex    thomas        5             BI         8

# %%
pd.merge(student_details,student_credentials, left_on='student_id', right_on='stud_id', how='inner')
# Out:
#    student_id first_name last_name  stud_id student_course  duration
# 0           1        sam      chan        1             ML         2
# 1           2        ben   charlie        2             DS         4
# 2           3        ven    mathew        3             AI         6

# %%
pd.merge(student_details,student_credentials, left_on='student_id', right_on='stud_id', how='left')
# Out:
#    student_id first_name last_name  stud_id student_course  duration
# 0           1        sam      chan      1.0             ML       2.0
# 1           2        ben   charlie      2.0             DS       4.0
# 2           3        ven    mathew      3.0             AI       6.0
# 3           4       alex    thomas      NaN            NaN       NaN

# %%
pd.merge(student_details,student_credentials, left_on='student_id', right_on='stud_id', how='right')
# Out:
#    student_id first_name last_name  stud_id student_course  duration
# 0         1.0        sam      chan        1             ML         2
# 1         2.0        ben   charlie        2             DS         4
# 2         3.0        ven    mathew        3             AI         6
# 3         NaN        NaN       NaN        5             BI         8

# %%
pd.merge(student_details,student_credentials, left_on='student_id', right_on='stud_id', how='outer')
# Out:
#    student_id first_name last_name  stud_id student_course  duration
# 0         1.0        sam      chan      1.0             ML       2.0
# 1         2.0        ben   charlie      2.0             DS       4.0
# 2         3.0        ven    mathew      3.0             AI       6.0
# 3         4.0       alex    thomas      NaN            NaN       NaN
# 4         NaN        NaN       NaN      5.0             BI       8.0

# %%
raw_data={'country':['india','africa','australia','england','america'],
          'area':[17.25,12.25,13.25,18.25,15.5],
          'vehicles':[320,420,500,650,800]}

# %%
raw_data
# Out:
# {'country': ['india', 'africa', 'australia', 'england', 'america'],
#  'area': [17.25, 12.25, 13.25, 18.25, 15.5],
#  'vehicles': [320, 420, 500, 650, 800]}

# %%
country_data=pd.DataFrame(raw_data,columns=['country','area','vehicles'])

# %%
country_data

country_data.index=['IND','AFR','AUS','ENG','AME']

# %%
country_data
# Out:
#        country   area  vehicles
# IND      india  17.25       320
# AFR     africa  12.25       420
# AUS  australia  13.25       500
# ENG    england  18.25       650
# AME    america  15.50       800

# %%
country_data.loc['AUS']
# Out:
# country     australia
# area            13.25
# vehicles          500
# Name: AUS, dtype: object

# %%
type(country_data.loc['AUS'])
# Out:
# pandas.core.series.Series

# %%
country_data.loc[['AUS']]
# Out:
#        country   area  vehicles
# AUS  australia  13.25       500

# %%
type(country_data.loc[['AUS']])
# Out:
# pandas.core.frame.DataFrame

# %%
country_data.loc[['AUS']]
# Out:
#        country   area  vehicles
# AUS  australia  13.25       500

# %%
country_data.loc[['IND','AFR','AUS'],['vehicles','area']]
# Out:
#      vehicles   area
# IND       320  17.25
# AFR       420  12.25
# AUS       500  13.25

# %%
import os

# %%
os.chdir('Downloads')

# %%
os.getcwd()
# Out:
# 'C:\\Users\\user\\Downloads'

# %%
tips=pd.read_csv('tips.csv')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# 5         25.29  4.71    Male     No   Sun  Dinner     4
# 6          8.77  2.00    Male     No   Sun  Dinner     2
# 7         26.88  3.12    Male     No   Sun  Dinner     4
# 8         15.04  1.96    Male     No   Sun  Dinner     2
# 9         14.78  3.23    Male     No   Sun  Dinner     2
# 10        10.27  1.71    Male     No   Sun  Dinner     2
# 11        35.26  5.00  Female     No   Sun  Dinner     4
# 12        15.42  1.57    Male     No   Sun  Dinner     2
# 13        18.43  3.00    Male     No   Sun  Dinner     4
# 14        14.83  3.02  Female     No   Sun  Dinner     2
# ...

# %%
len(tips)
# Out:
# 244

# %%
list(tips.columns)
# Out:
# ['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size']

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.head(10)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4
# 6        8.77  2.00    Male     No  Sun  Dinner     2
# 7       26.88  3.12    Male     No  Sun  Dinner     4
# 8       15.04  1.96    Male     No  Sun  Dinner     2
# 9       14.78  3.23    Male     No  Sun  Dinner     2

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
# total_bill    244 non-null float64
# tip           244 non-null float64
# sex           244 non-null object
# smoker        244 non-null object
# day           244 non-null object
# time          244 non-null object
# size          244 non-null int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.4+ KB

# %%
tips.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
tips.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
tips.tail(10)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 234       15.53  3.00    Male    Yes   Sat  Dinner     2
# 235       10.07  1.25    Male     No   Sat  Dinner     2
# 236       12.60  1.00    Male    Yes   Sat  Dinner     2
# 237       32.83  1.17    Male    Yes   Sat  Dinner     2
# 238       35.83  4.67  Female     No   Sat  Dinner     3
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
tips=tips.rename(columns={'total_bill':'totalbill'})

# %%
tips
# Out:
#      totalbill   tip     sex smoker   day    time  size
# 0        16.99  1.01  Female     No   Sun  Dinner     2
# 1        10.34  1.66    Male     No   Sun  Dinner     3
# 2        21.01  3.50    Male     No   Sun  Dinner     3
# 3        23.68  3.31    Male     No   Sun  Dinner     2
# 4        24.59  3.61  Female     No   Sun  Dinner     4
# 5        25.29  4.71    Male     No   Sun  Dinner     4
# 6         8.77  2.00    Male     No   Sun  Dinner     2
# 7        26.88  3.12    Male     No   Sun  Dinner     4
# 8        15.04  1.96    Male     No   Sun  Dinner     2
# 9        14.78  3.23    Male     No   Sun  Dinner     2
# 10       10.27  1.71    Male     No   Sun  Dinner     2
# 11       35.26  5.00  Female     No   Sun  Dinner     4
# 12       15.42  1.57    Male     No   Sun  Dinner     2
# 13       18.43  3.00    Male     No   Sun  Dinner     4
# 14       14.83  3.02  Female     No   Sun  Dinner     2
# 15       21.58  3.92    Male     No   Sun  Dinner     2
# ...

# %%
tips=tips.rename(columns={'totalbill':'total_bill'})

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# 5         25.29  4.71    Male     No   Sun  Dinner     4
# 6          8.77  2.00    Male     No   Sun  Dinner     2
# 7         26.88  3.12    Male     No   Sun  Dinner     4
# 8         15.04  1.96    Male     No   Sun  Dinner     2
# 9         14.78  3.23    Male     No   Sun  Dinner     2
# 10        10.27  1.71    Male     No   Sun  Dinner     2
# 11        35.26  5.00  Female     No   Sun  Dinner     4
# 12        15.42  1.57    Male     No   Sun  Dinner     2
# 13        18.43  3.00    Male     No   Sun  Dinner     4
# 14        14.83  3.02  Female     No   Sun  Dinner     2
# ...

# %%
tips['mycal']=tips.total_bill*tips.tip

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size     mycal
# 0         16.99  1.01  Female     No   Sun  Dinner     2   17.1599
# 1         10.34  1.66    Male     No   Sun  Dinner     3   17.1644
# 2         21.01  3.50    Male     No   Sun  Dinner     3   73.5350
# 3         23.68  3.31    Male     No   Sun  Dinner     2   78.3808
# 4         24.59  3.61  Female     No   Sun  Dinner     4   88.7699
# 5         25.29  4.71    Male     No   Sun  Dinner     4  119.1159
# 6          8.77  2.00    Male     No   Sun  Dinner     2   17.5400
# 7         26.88  3.12    Male     No   Sun  Dinner     4   83.8656
# 8         15.04  1.96    Male     No   Sun  Dinner     2   29.4784
# 9         14.78  3.23    Male     No   Sun  Dinner     2   47.7394
# 10        10.27  1.71    Male     No   Sun  Dinner     2   17.5617
# 11        35.26  5.00  Female     No   Sun  Dinner     4  176.3000
# 12        15.42  1.57    Male     No   Sun  Dinner     2   24.2094
# ...

# %%
tips=tips.drop('mycal',1)

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# 5         25.29  4.71    Male     No   Sun  Dinner     4
# 6          8.77  2.00    Male     No   Sun  Dinner     2
# 7         26.88  3.12    Male     No   Sun  Dinner     4
# 8         15.04  1.96    Male     No   Sun  Dinner     2
# 9         14.78  3.23    Male     No   Sun  Dinner     2
# 10        10.27  1.71    Male     No   Sun  Dinner     2
# 11        35.26  5.00  Female     No   Sun  Dinner     4
# 12        15.42  1.57    Male     No   Sun  Dinner     2
# 13        18.43  3.00    Male     No   Sun  Dinner     4
# 14        14.83  3.02  Female     No   Sun  Dinner     2
# ...

# %%
tips[['total_bill','tip','smoker','time']].head(5)
# Out:
#    total_bill   tip smoker    time
# 0       16.99  1.01     No  Dinner
# 1       10.34  1.66     No  Dinner
# 2       21.01  3.50     No  Dinner
# 3       23.68  3.31     No  Dinner
# 4       24.59  3.61     No  Dinner

# %%
tips[tips['time']=='Dinner'].head(5)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips[(tips['time']=='Dinner') & (tips['tip']>5.00)]
# Out:
#      total_bill    tip     sex smoker  day    time  size
# 23        39.42   7.58    Male     No  Sat  Dinner     4
# 44        30.40   5.60    Male     No  Sun  Dinner     4
# 47        32.40   6.00    Male     No  Sun  Dinner     4
# 52        34.81   5.20  Female     No  Sun  Dinner     4
# 59        48.27   6.73    Male     No  Sat  Dinner     4
# 116       29.93   5.07    Male     No  Sun  Dinner     4
# 155       29.85   5.14  Female     No  Sun  Dinner     5
# 170       50.81  10.00    Male    Yes  Sat  Dinner     3
# 172        7.25   5.15    Male    Yes  Sun  Dinner     2
# 181       23.33   5.65    Male    Yes  Sun  Dinner     2
# 183       23.17   6.50    Male    Yes  Sun  Dinner     4
# 211       25.89   5.16    Male    Yes  Sat  Dinner     4
# 212       48.33   9.00    Male     No  Sat  Dinner     4
# 214       28.17   6.50  Female    Yes  Sat  Dinner     3
# 239       29.03   5.92    Male     No  Sat  Dinner     3

# %%
tips[(tips.size>=5) | (tips['total_bill']>45)]
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# 5         25.29  4.71    Male     No   Sun  Dinner     4
# 6          8.77  2.00    Male     No   Sun  Dinner     2
# 7         26.88  3.12    Male     No   Sun  Dinner     4
# 8         15.04  1.96    Male     No   Sun  Dinner     2
# 9         14.78  3.23    Male     No   Sun  Dinner     2
# 10        10.27  1.71    Male     No   Sun  Dinner     2
# 11        35.26  5.00  Female     No   Sun  Dinner     4
# 12        15.42  1.57    Male     No   Sun  Dinner     2
# 13        18.43  3.00    Male     No   Sun  Dinner     4
# 14        14.83  3.02  Female     No   Sun  Dinner     2
# ...

# %%
tips[tips.time.isna()]
# Out:
# Empty DataFrame
# Columns: [total_bill, tip, sex, smoker, day, time, size]
# Index: []

# %%
tips[tips.time.notna()]
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# 5         25.29  4.71    Male     No   Sun  Dinner     4
# 6          8.77  2.00    Male     No   Sun  Dinner     2
# 7         26.88  3.12    Male     No   Sun  Dinner     4
# 8         15.04  1.96    Male     No   Sun  Dinner     2
# 9         14.78  3.23    Male     No   Sun  Dinner     2
# 10        10.27  1.71    Male     No   Sun  Dinner     2
# 11        35.26  5.00  Female     No   Sun  Dinner     4
# 12        15.42  1.57    Male     No   Sun  Dinner     2
# 13        18.43  3.00    Male     No   Sun  Dinner     4
# 14        14.83  3.02  Female     No   Sun  Dinner     2
# ...

# %%
tips.groupby('sex').count()
# Out:
#         total_bill  tip  smoker  day  time  size
# sex
# Female          87   87      87   87    87    87
# Male           157  157     157  157   157   157

# %%
tips.groupby('sex').size()
# Out:
# sex
# Female     87
# Male      157
# dtype: int64

# %%
import numpy as np

# %%
tips.groupby('day').agg({'tip':np.mean, 'day':np.size})
# Out:
#            tip  day
# day
# Fri   2.734737   19
# Sat   2.993103   87
# Sun   3.255132   76
# Thur  2.771452   62

# %%
tips.groupby(['smoker','day']).agg({'tip':[np.mean, np.size]})
# Out:
#                   tip
#                  mean  size
# smoker day
# No     Fri   2.812500   4.0
#        Sat   3.102889  45.0
#        Sun   3.167895  57.0
#        Thur  2.673778  45.0
# Yes    Fri   2.714000  15.0
#        Sat   2.875476  42.0
#        Sun   3.516842  19.0
#        Thur  3.030000  17.0
